# %%
# !pip install google-adk
# Out:
# Requirement already satisfied: google-adk in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (1.31.1)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (6.0.2)
# Requirement already satisfied: aiosqlite>=0.21.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.22.1)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (4.9.0)
# Requirement already satisfied: authlib<2.0.0,>=1.6.6 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.7.0)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (8.2.1)
# Requirement already satisfied: fastapi<1.0.0,>=0.124.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.136.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.194.0)
# Requirement already satisfied: google-auth>=2.47.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk) (2.49.2)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.148.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (1.148.1)
# Requirement already satisfied: google-cloud-bigquery-storage>=2.0.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.37.0)
# Requirement already satisfied: google-cloud-bigquery>=2.2.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (3.41.0)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.36.0)
# Requirement already satisfied: google-cloud-dataplex<3.0.0,>=1.7.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.18.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-pubsub<3.0.0,>=2.0.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.37.0)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.27.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (3.65.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.38.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=2.18.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (3.10.1)
# Requirement already satisfied: google-genai<2.0.0,>=1.72.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.73.1)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.21)
# Requirement already satisfied: httpx<1.0.0,>=0.27.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.28.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.24.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.27.0)
# Requirement already satisfied: opentelemetry-api<1.39.0,>=1.36.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<1.39.0,>=1.36.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.38.0)
# Requirement already satisfied: pyarrow>=14.0.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (24.0.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.13.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.33.1)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (1.17.3)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (2.0.40)
# Requirement already satisfied: starlette<1.0.0,>=0.49.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.52.1)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (9.1.2)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (0.34.3)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from authlib<2.0.0,>=1.6.6->google-adk) (47.0.0)
# Requirement already satisfied: joserfc>=1.6.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from authlib<2.0.0,>=1.6.6->google-adk) (1.6.4)
# Requirement already satisfied: colorama in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from click<9.0.0,>=8.1.8->google-adk) (0.4.6)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from fastapi<1.0.0,>=0.124.1->google-adk) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from fastapi<1.0.0,>=0.124.1->google-adk) (0.0.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk) (0.4.2)
# Requirement already satisfied: pyopenssl>=20.0.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-auth[pyopenssl]>=2.47.0->google-adk) (26.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.148.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (2.30.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.148.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (1.27.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.148.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (6.33.6)
# Requirement already satisfied: packaging>=14.3 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.148.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (24.2)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.148.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (1.17.0)
# Requirement already satisfied: docstring_parser<1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.148.1->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (0.18.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (1.19.0)
# Requirement already satisfied: google-cloud-logging<4 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (3.15.0)
# Requirement already satisfied: google-cloud-iam in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (2.22.0)
# Requirement already satisfied: aiohttp in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (3.11.18)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery>=2.2.0->google-adk) (2.8.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigquery-storage>=2.0.0->google-adk) (1.80.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigtable>=2.32.0->google-adk) (0.14.4)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-bigtable>=2.32.0->google-adk) (1.8.0)
# Requirement already satisfied: grpcio-status>=1.33.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-pubsub<3.0.0,>=2.0.0->google-adk) (1.80.0)
# Requirement already satisfied: sqlparse>=0.4.4 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.5)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: opentelemetry-semantic-conventions>=0.43b0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.59b0)
# Requirement already satisfied: google-cloud-monitoring>=2.16.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (2.30.0)
# Requirement already satisfied: mmh3>=4.1.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (5.2.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-genai<2.0.0,>=1.72.0->google-adk) (1.9.0)
# Requirement already satisfied: certifi in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.27.0->google-adk) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from httpx<1.0.0,>=0.27.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.0->google-adk) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from jsonschema<5.0.0,>=4.23.0->google-adk) (0.30.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->google-adk) (0.4.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->google-adk) (2.9.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->google-adk) (2.12.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->google-adk) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->google-adk) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from mcp<2.0.0,>=1.24.0->google-adk) (1.8.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-api<1.39.0,>=1.36.0->google-adk) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.38.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.12.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.3 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3.0.0,>=2.12.0->google-adk) (2.46.3)
# Requirement already satisfied: six>=1.5 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.4.0)
# Requirement already satisfied: greenlet>=1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.1)
# Requirement already satisfied: alembic in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.18.4)
# Requirement already satisfied: tzdata in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from tzlocal<6.0,>=5.3->google-adk) (2025.2)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from cryptography->authlib<2.0.0,>=1.6.6->google-adk) (2.0.0)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (1.9.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (0.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<1.39.0,>=1.36.0->google-adk) (3.23.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.47.0->google-auth[pyopenssl]>=2.47.0->google-adk) (0.6.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.148.1->google-adk) (1.20.0)
# Requirement already satisfied: Mako in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.11)
# Requirement already satisfied: pycparser in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from cffi>=2.0.0->cryptography->authlib<2.0.0,>=1.6.6->google-adk) (3.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.2)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\Aizaz Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\Aizaz Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\Aizaz Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.genai import types
# Out:
# c:\Users\Aizaz Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages\authlib\_joserfc_helpers.py:8: AuthlibDeprecationWarning: authlib.jose module is deprecated, please use joserfc instead.
# It will be compatible before version 2.0.0.
#   from authlib.jose import ECKey
# c:\Users\Aizaz Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\adk\features\_feature_decorator.py:72: UserWarning: [EXPERIMENTAL] feature FeatureName.PLUGGABLE_AUTH is enabled.
#   check_feature_enabled()

# %%
from google.adk.tools import google_search

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\aizaz khan\appdata\local\programs\python\python312\lib\site-packages (1.1.0)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\Aizaz Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\Aizaz Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow-intel (C:\Users\Aizaz Khan\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Loading .env file in this notebook

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # ye .env file load karega
# Out:
# True

# %%
api_key = os.getenv("GOOGLE_API_KEY")

# %%
my_agent = Agent(
    name = 'Technical_Agent',
    model = "gemini-2.5-flash-lite",
    description = ' You are an expert crypto technical analyst specilized in Relative Strenght Index (RSI) and Moving Average Convergence Divergence (MACD) indicators.',
    instruction= """
                You are an expert crypto technical analyst specializing in RSI (Relative Strength Index) and MACD (Moving Average Convergence Divergence).

                You will be given:
                - RSI value (number)
                - MACD line value (number)
                - Signal line value (number)

                Your task is to analyze these indicators and provide a trading decision.

                Analysis Rules:

                1. RSI Analysis:
                - If RSI < 30 → market is oversold → BUY signal
                - If RSI > 70 → market is overbought → SELL signal
                - If RSI is between 30 and 70 → neutral

                2. MACD Analysis:
                - If MACD line > Signal line → bullish → supports BUY
                - If MACD line < Signal line → bearish → supports SELL

                3. Decision Logic:
                - If both RSI and MACD indicate BUY → Decision = BUY (Strong)
                - If both RSI and MACD indicate SELL → Decision = SELL (Strong)
                - If one indicates BUY and the other SELL → Decision = HOLD
                - If RSI is neutral and MACD is bullish → Decision = BUY (Moderate)
                - If RSI is neutral and MACD is bearish → Decision = SELL (Moderate)

                4. Confidence Score:
                - Strong agreement → 80-90%
                - Moderate signal → 60-75%
                - Conflict / HOLD → 40-50%

                Output Rules (STRICT):
                - Return ONLY the following format
                - Do NOT add extra text
                - Do NOT explain beyond one short sentence

                Format:

                Decision: <BUY / SELL / HOLD>
                Confidence: <number>%
                Reason: <one short sentence explaining why>

                 """,
)

# %% [markdown]
# Run the agent

# %%
runner = InMemoryRunner(agent = my_agent)
print("Runner created successfully")
# Out:
# Runner created successfully

# %%
response = await runner.run_debug( "RSI = 25, MACD = 1.2, Signal = 0.8")
# Out:
#  ### Created new session: debug_session_id
#
# User > RSI = 25, MACD = 1.2, Signal = 0.8
# Technical_Agent > Decision: BUY
# Confidence: 85%
# Reason: RSI indicates oversold conditions, and MACD is bullish.
